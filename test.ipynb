# %%
import google.generativeai as genai
import os

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyCCXrbjc8bbh_g4mRtkpx9xR19nWrW-nm8"

# %%
genai.configure(api_key = os.getenv("GOOGLE_API_KEY"))

# %%
model = genai.GenerativeModel(model_name = "gemini-2.0-flash")

# %%
question = "draw a line graph to show the car sales in the past week"

# %%
def question_analyze_prompt(question: str) -> str:
    return (
        f"""
You are an expert at analyzing a QUESTION and breaking it down into key visual components for creating a **clear, educational diagram**.

Your tasks:
1. **Identify** the type of diagram requested (e.g., flowchart, bar graph, pie chart, geometric shapes, etc.).
2. **List all visual components** needed for the diagram, including their approximate positions and shapes.
3. **Specify colors** for each component (use only black and white).
4. **Label all parts** clearly and mention any text annotations.
5. **Follow specific rules** depending on the type of diagram.

---

## GENERAL RULES:
- Create a **simple and minimal** interpretation of the question.
- List each visual component in detail (shape, size or relative position, label).
- Only use black and white colors.
- Focus on pedagogical clarity (make it easy to understand).

---

## DIAGRAM-SPECIFIC EXTRA RULES:

### 1️⃣ Simple geometrical shapes (e.g., square, rectangle, triangle, trapezium):
- Label all corners clearly (e.g., A, B, C, D).
- Specify the shape type explicitly.
- Mention approximate positions or relative layout.

---

## OUTPUT FORMAT:
- Only list **components**; do not include explanations or extra text.
- Be structured and concise.

---

### QUESTION:
{question}
    """
    )

# %%
analyze_prompt = question_analyze_prompt(question)
response = model.generate_content(analyze_prompt)
print(response.text)
# Out:
# Okay, I will analyze the question and break it down into visual components for a line graph.
#
# **1. Type of Diagram:** Line Graph
#
# **2. Visual Components:**
#
# *   **Horizontal Axis (x-axis):**
#     *   Shape: Straight line, horizontal.
#     *   Position: Bottom of the graph area.
#     *   Color: Black.
#     *   Label: "Day of the Week".
#     *   Tick Marks: Seven equally spaced vertical lines along the x-axis.
# *   **Vertical Axis (y-axis):**
#     *   Shape: Straight line, vertical.
#     *   Position: Left side of the graph area.
#     *   Color: Black.
#     *   Label: "Number of Cars Sold".
#     *   Tick Marks: Several equally spaced horizontal lines along the y-axis.
# *   **Data Points:**
#     *   Shape: Small circles.
#     *   Position: Varies, depending on the data for each day (example: Monday - 10 cars, Tuesday - 15 cars, etc. up to Sunday).
#     *   Color: Black.
# *   **Line:**
#     *   Shape: Straight lines connecting the data points in chronological order (Monday to Tuesday, Tuesday to Wednesday, etc.).
#     *   Color: Black.
# *   **Labels for x-axis Tick Marks:**
#     *   Shape: Text labels.
#     *   Position: Below each tick mark on the x-axis.
#     *   Labels: "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday".
#     *   Color: Black.
# *   **Labels for y-axis Tick Marks:**
#     *   Shape: Text labels.
#     *   Position: To the left of each tick mark on the y-axis.
#     *   Labels: Numerical values representing the number of cars sold (e.g., 0, 5, 10, 15, 20, etc.).
#     *   Color: Black.
# *   **Graph Title:**
#     *   Shape: Text.
#     *   Position: Top center of the graph.
#     *   Label: "Car Sales in the Past Week".
#     *   Color: Black.
#
# **3. Colors:**
#
# *   All components: Black and White

# %%
elements = response.text

# %%
def steps_maker_prompt(elements: str) -> str:
    return (
    f"""
You are an expert in designing clear, pedagogically effective diagrams to be used in educational materials (such as exam papers or textbooks).

Based on the provided **ELEMENTS**, outline a **high-level pseudocode plan** for drawing the diagram using **HTML canvas and JavaScript**.

---

## Your pseudocode plan should include:
1. **Shapes to be drawn**:
   - Specify each shape (e.g., rectangle, circle, line, path).
   - Mention approximate positions and sizes if relevant.

2. **Drawing order**:
   - Describe in what sequence the shapes should be drawn (from background to foreground).

3. **Helper functions**:
   - List any reusable functions you would define.
   - For each helper function, describe:
     - **Input parameters**
     - **Expected output**
     - **What the function does (action description)**

---

## Important instructions:
- Return **only the pseudocode**, do not include actual HTML or JavaScript code.
- Use clear and concise steps.
- Focus on pedagogical clarity and logical structure.

---

### ELEMENTS:
{elements}
    """
    )

# %%
steps_prompt = steps_maker_prompt(elements)
response = model.generate_content(steps_prompt)
print(response.text)
# Out:
# ```
# // Pseudocode for Line Graph Generation using HTML Canvas and JavaScript
#
# // 1. Canvas Setup:
# //    - Get canvas element from HTML.
# //    - Get 2D rendering context.
# //    - Define canvas dimensions (width, height).
# //    - Define margins (top, bottom, left, right) for graph area.
#
# // 2. Data Definition:
# //    - Define data points as an array of objects.
# //      Example: [{day: "Monday", sales: 10}, {day: "Tuesday", sales: 15}, ...]
# //    - Define labels for x-axis (days of the week).
# //    - Define max sales value for y-axis scaling.
#
# // 3. Helper Functions:
#
# //    3.1. `mapValue(value, start1, stop1, start2, stop2)`:
# //        - Input: `value` (number to map), `start1` (min of input range), `stop1` (max of input range), `start2` (min of output range), `stop2` (max of output range).
# //        - Output: Mapped `value` within the output range [start2, stop2].
# //        - Action: Linear mapping function to scale values from one range to another.
#
# //    3.2. `drawLine(x1, y1, x2, y2, color, lineWidth)`:
# //        - Input: `x1`, `y1` (starting coordinates), `x2`, `y2` (ending coordinates), `color` (line color), `lineWidth` (line width).
# //        - Output: None.
# //        - Action: Draws a line segment on the canvas.
#
# //    3.3. `drawCircle(x, y, radius, color)`:
# //        - Input: `x`, `y` (center coordinates), `radius`, `color`.
# //        - Output: None.
# //        - Action: Draws a filled circle on the canvas.
#
# //    3.4. `drawText(text, x, y, color, alignment, fontSize)`:
# //        - Input: `text` (string), `x`, `y` (coordinates), `color`, `alignment` (left, center, right), `fontSize`.
# //        - Output: None.
# //        - Action: Draws text on the canvas.
#
# // 4. Drawing the Graph:
#
# //    4.1. Draw Graph Title:
# //        - Calculate title position (centered at top).
# //        - Call `drawText()` to draw the title.
#
# //    4.2. Draw X-Axis:
# //        - Calculate x-axis start and end points.
# //        - Call `drawLine()` to draw the x-axis.
# //        - Calculate spacing between x-axis tick marks.
#
# //    4.3. Draw X-Axis Tick Marks and Labels:
# //        - Loop through the x-axis labels (days of the week).
# //        - Calculate the x position for each tick mark.
# //        - Call `drawLine()` to draw the vertical tick mark.
# //        - Call `drawText()` to draw the corresponding label below the tick mark.
#
# //    4.4. Draw Y-Axis:
# //        - Calculate y-axis start and end points.
# //        - Call `drawLine()` to draw the y-axis.
# //        - Determine number of y-axis tick marks.
# //        - Calculate spacing between y-axis tick marks.
#
# //    4.5. Draw Y-Axis Tick Marks and Labels:
# //        - Loop through the y-axis values (number of cars sold).
# //        - Calculate the y position for each tick mark based on mapValue function.
# //        - Call `drawLine()` to draw the horizontal tick mark.
# //        - Call `drawText()` to draw the corresponding label to the left of the tick mark.
#
# //    4.6. Draw Data Points and Connecting Lines:
# //        - Loop through the data points.
# //        - For each data point:
# //            - Calculate the x position based on the day of the week.
# //            - Calculate the y position using `mapValue()` to scale the sales value to the canvas height.
# //            - Call `drawCircle()` to draw the data point.
# //            - If it's not the first data point:
# //                - Draw a line from the previous data point to the current data point using `drawLine()`.
#
# ```

# %%
pseudocode = response.text

# %%
def drawer_prompt(scene: str, pseudocode: str) -> str:
    return (
        f"""
        You are a expert at analyzing a given PSEUDOCODE and generating complete runnable code for that using HTML canvas and JS.
        Include HTML boilerplate, canvas element, and full JS logic inside the HTML code itself.

        SCENE: {scene}
        PSEUDOCODE: {pseudocode}

        Return only the code.
        """
    )

# %%
da_prompt = drawer_prompt(question, pseudocode)
response = model.generate_content(da_prompt)

# %%
print(response.text)
# Out:
# ```html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Car Sales Line Graph</title>
# <style>
#   body {
#     font-family: sans-serif;
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     min-height: 100vh;
#     margin: 0;
#     background-color: #f0f0f0;
#   }
#
#   canvas {
#     border: 1px solid #ccc;
#     background-color: #fff;
#   }
# </style>
# </head>
# <body>
#
# <canvas id="myCanvas"></canvas>
#
# <script>
# // 1. Canvas Setup:
# const canvas = document.getElementById("myCanvas");
# const ctx = canvas.getContext("2d");
# const canvasWidth = 800;
# const canvasHeight = 600;
# canvas.width = canvasWidth;
# canvas.height = canvasHeight;
#
# const margin = {
#   top: 50,
#   bottom: 50,
#   left: 80,
#   right: 50
# };
#
# // 2. Data Definition:
# const data = [
#   { day: "Monday", sales: 10 },
#   { day: "Tuesday", sales: 15 },
#   { day: "Wednesday", sales: 13 },
#   { day: "Thursday", sales: 20 },
#   { day: "Friday", sales: 25 },
#   { day: "Saturday", sales: 30 },
#   { day: "Sunday", sales: 22 }
# ];
#
# const labels = data.map(item => item.day);
# const maxSales = Math.max(...data.map(item => item.sales));
#
# // 3. Helper Functions:
#
# function mapValue(value, start1, stop1, start2, stop2) {
#   return start2 + (stop2 - start2) * ((value - start1) / (stop1 - start1));
# }
#
# function drawLine(x1, y1, x2, y2, color, lineWidth) {
#   ctx.beginPath();
#   ctx.strokeStyle = color;
#   ctx.lineWidth = lineWidth;
#   ctx.moveTo(x1, y1);
#   ctx.lineTo(x2, y2);
#   ctx.stroke();
# }
#
# function drawCircle(x, y, radius, color) {
#   ctx.beginPath();
#   ctx.arc(x, y, radius, 0, 2 * Math.PI);
#   ctx.fillStyle = color;
#   ctx.fill();
# }
#
# function drawText(text, x, y, color, alignment, fontSize) {
#   ctx.fillStyle = color;
#   ctx.font = `${fontSize}px sans-serif`;
#   ctx.textAlign = alignment;
#   ctx.fillText(text, x, y);
# }
#
# // 4. Drawing the Graph:
#
# // 4.1. Draw Graph Title:
# const title = "Car Sales in the Past Week";
# const titleX = canvasWidth / 2;
# const titleY = margin.top / 2;
# drawText(title, titleX, titleY, "black", "center", 20);
#
# // 4.2. Draw X-Axis:
# const xAxisStartY = canvasHeight - margin.bottom;
# const xAxisEndY = xAxisStartY;
# const xAxisStartX = margin.left;
# const xAxisEndX = canvasWidth - margin.right;
# drawLine(xAxisStartX, xAxisStartY, xAxisEndX, xAxisEndY, "black", 2);
#
# // 4.3. Draw X-Axis Tick Marks and Labels:
# const numXAxisTicks = labels.length;
# const xAxisTickSpacing = (xAxisEndX - xAxisStartX) / (numXAxisTicks - 1);
#
# for (let i = 0; i < numXAxisTicks; i++) {
#   const tickX = xAxisStartX + i * xAxisTickSpacing;
#   const tickYStart = xAxisStartY;
#   const tickYEnd = xAxisStartY + 5;
#   drawLine(tickX, tickYStart, tickX, tickYEnd, "black", 1);
#
#   const labelX = tickX;
#   const labelY = xAxisStartY + 20;
#   drawText(labels[i], labelX, labelY, "black", "center", 12);
# }
#
# // 4.4. Draw Y-Axis:
# const yAxisStartX = margin.left;
# const yAxisEndX = yAxisStartX;
# const yAxisStartY = margin.top;
# const yAxisEndY = canvasHeight - margin.bottom;
# drawLine(yAxisStartX, yAxisStartY, yAxisEndX, yAxisEndY, "black", 2);
#
# // 4.5. Draw Y-Axis Tick Marks and Labels:
# const numYAxisTicks = 5;
# const yAxisTickSpacing = (yAxisEndY - yAxisStartY) / (numYAxisTicks - 1);
#
# for (let i = 0; i < numYAxisTicks; i++) {
#   const salesValue = Math.round(mapValue(i, 0, numYAxisTicks - 1, 0, maxSales));
#   const tickY = yAxisEndY - i * yAxisTickSpacing;
#   const tickXStart = yAxisStartX - 5;
#   const tickXEnd = yAxisStartX;
#   drawLine(tickXStart, tickY, tickXEnd, tickY, "black", 1);
#
#   const labelX = yAxisStartX - 10;
#   const labelY = tickY + 4;
#   drawText(salesValue.toString(), labelX, labelY, "black", "right", 12);
# }
#
# // 4.6. Draw Data Points and Connecting Lines:
# const graphAreaHeight = canvasHeight - margin.top - margin.bottom;
#
# let prevX = null;
# let prevY = null;
#
# for (let i = 0; i < data.length; i++) {
#   const day = data[i].day;
#   const sales = data[i].sales;
#
#   const x = xAxisStartX + i * xAxisTickSpacing;
#   const y = yAxisEndY - mapValue(sales, 0, maxSales, 0, graphAreaHeight);
#
#   drawCircle(x, y, 5, "blue");
#
#   if (prevX !== null && prevY !== null) {
#     drawLine(prevX, prevY, x, y, "red", 2);
#   }
#
#   prevX = x;
#   prevY = y;
# }
# </script>
#
# </body>
# </html>
# ```

# %%
file_name = "test.html"
html_code = response.text

with open(file_name, "w", encoding="utf-8") as file:
    file.write(html_code)

# %%
output = response.text

# %%
def validation_rules_prompt(pseudocode: str) -> str:
    return (
        f"""
        You are an expert in analyzing PSEUDOCODE for image generation and designing validation steps 
        to crosss check with the final code output. Make sure to read the PSEUDOCODE thoroughly and create 
        a numbered list of validation rules that can be followed to verify if the output matches the design.

        Some common rules to include are:
            - Presence of all components and elements
            - Correct positioning and relative layout of elements
            - Proper shapes, sizes, coordinates and positioning of elements
            - Directional indicators point in the correct direction(e.g. arrows point in the right direction, etc.)
            - Make sure all the components are within the canvas
            - Make sure all the labels are close to the representing components
            - Make sure there is no major overlapping of components
            - Do not include javascript linkage rule
            

        PSEUDOCODE: {pseudocode}
        Make sure to review your answer after generation.
        """
    )

# %%
validation_prompt = validation_rules_prompt(pseudocode)
response = model.generate_content(validation_prompt)

# %%
print(response.text)
# Out:
# Okay, I have analyzed the pseudocode for drawing a rectangle with dimension lines and labels using HTML Canvas. Here's a list of validation rules to ensure the final code output matches the design:
#
# 1.  **Canvas Initialization:**
#     *   Verify that the canvas element is correctly retrieved from the HTML.
#     *   Confirm that the 2D rendering context is obtained successfully.
#     *   Ensure the canvas width and height are set to the intended values (e.g., 500x300, but could be adjusted).
#
# 2.  **Rectangle Properties:**
#     *   Check that `rectangleWidth` is set to the correct value (200 in the pseudocode, but the code could adjust it).
#     *   Verify `rectangleHeight` is set to the correct value (100 in the pseudocode, but the code could adjust it).
#     *   Confirm that `rectangleX` is calculated correctly to center the rectangle horizontally within the canvas. `rectangleX` should be `(canvasWidth / 2) - (rectangleWidth / 2)`.
#     *   Confirm that `rectangleY` is calculated correctly to center the rectangle vertically within the canvas. `rectangleY` should be `(canvasHeight / 2) - (rectangleHeight / 2)`.
#     *   Check that `lineColor` is set to 'black'.
#     *   Verify `lineWidth` is set to 2.
#
# 3.  **Rectangle Drawing:**
#     *   Ensure the rectangle is drawn using `ctx.strokeRect()` with the calculated `rectangleX`, `rectangleY`, `rectangleWidth`, and `rectangleHeight`.
#     *   Verify that the rectangle's outline color matches `lineColor` ('black').
#     *   Confirm that the rectangle's outline width matches `lineWidth` (2 pixels).
#
# 4.  **Dimension Line (Width - Longer Side):**
#     *   Verify that `dimLineOffset` is set to the correct distance from the rectangle (20).
#     *   Confirm `dimLineWidthStartX` is calculated correctly: `rectangleX - dimLineOffset`.
#     *   Confirm `dimLineWidthStartY` is set to `rectangleY`.
#     *   Confirm `dimLineWidthEndX` is calculated correctly: `rectangleX - dimLineOffset + rectangleWidth`.
#     *   Confirm `dimLineWidthEndY` is set to `rectangleY`.
#     *   Check that an arrow is drawn using the `drawArrow` function with the correct start and end coordinates (`dimLineWidthStartX`, `dimLineWidthStartY`, `dimLineWidthEndX`, `dimLineWidthEndY`), `headLength` (10), and `headAngle` (Math.PI/6). The arrow should point from left to right along the top edge of the canvas.
#
# 5.  **Dimension Line (Height - Shorter Side):**
#     *   Confirm `dimLineHeightStartX` is set to `rectangleX`.
#     *   Confirm `dimLineHeightStartY` is calculated correctly: `rectangleY - dimLineOffset`.
#     *   Confirm `dimLineHeightEndX` is set to `rectangleX`.
#     *   Confirm `dimLineHeightEndY` is calculated correctly: `rectangleY - dimLineOffset + rectangleHeight`.
#     *   Check that an arrow is drawn using the `drawArrow` function with the correct start and end coordinates (`dimLineHeightStartX`, `dimLineHeightStartY`, `dimLineHeightEndX`, `dimLineHeightEndY`), `headLength` (10), and `headAngle` (Math.PI/6). The arrow should point from top to bottom along the left edge of the canvas.
#
# 6.  **Labels (Width and Height):**
#     *   Verify the font is set to "16px Arial".
#     *   Confirm `textColor` is set to 'black'.
#     *   Check `labelWidthX` is calculated correctly: `(dimLineWidthStartX + dimLineWidthEndX) / 2`.
#     *   Check `labelWidthY` is calculated correctly: `dimLineWidthStartY - 10`.
#     *   Confirm that the text "30 cm" (or a code adjusted value) is drawn using the `drawText` function at coordinates (`labelWidthX`, `labelWidthY`) with "center" alignment. The label should be above the width dimension line, horizontally centered.
#     *   Check `labelHeightX` is calculated correctly: `dimLineHeightStartX - 25`.
#     *   Check `labelHeightY` is calculated correctly: `(dimLineHeightStartY + dimLineHeightEndY) / 2`.
#     *   Confirm that the text "15 cm" (or a code adjusted value) is drawn using the `drawText` function at coordinates (`labelHeightX`, `labelHeightY`) with "center" alignment. The label should be to the left of the height dimension line, vertically centered.
#
# 7.  **Helper Function Validation:**
#     *   Ensure the `drawArrow` function correctly draws an arrow (line with an arrowhead) between two points.  Pay attention to the arrowhead's length and angle.
#     *   Ensure the `drawText` function correctly draws text at the specified coordinates with the specified alignment.
#
# 8.  **Canvas Boundaries:**
#     *   Verify that all parts of the rectangle, dimension lines, arrows, and labels are fully visible within the canvas boundaries.  No elements should be clipped or cut off.
#
# 9. **No Major Overlapping:**
#    *   Verify that there is no significant overlapping of the rectangle, dimension lines, arrows, and labels that would obscure their visibility or readability.
#
# These validation rules cover the key aspects of the pseudocode and should help in verifying the correctness of the final implementation. Remember to adapt the specific values (like dimensions and offsets) in the rules if the code allows for customization or uses different default values.

# %%
validation_rules = response.text

# %%
def validation_checker_prompt(validation_rules: str, code: str) -> str:
    return (
        f"""
        You are an experting in comparing a CODE output with a set of VALIDATION RULES and making sure all the rules are 
        satisfied or not. Return whichever rules are not satisfied and a brief info on what the issue is, do not resolve the issue.

        VALIDATION RULES: {validation_rules}
        CODE: {code}

        """
    )

# %%
checker_prompt = validation_checker_prompt(validation_rules, output)
response = model.generate_content(checker_prompt)

# %%
print(response.text)
# Out:
# Okay, I've analyzed the provided HTML/JavaScript code against the validation rules. Here's a breakdown of the rules that are not satisfied:
#
# *   **Rule 4 (Dimension Line (Width - Longer Side)):**
#     *   **Issue:** `dimLineWidthEndX` is calculated as `rectangleX + rectangleWidth + dimLineOffset`.  It should be `rectangleX + rectangleWidth + dimLineOffset`
#     *   **Issue:** The arrows are not drawn at the correct endpoint. The `drawArrow` function's end points are set to the corner of the rectangle. The arrows needs to point to the start and end of the dimension line.
# *   **Rule 5 (Dimension Line (Height - Shorter Side)):**
#     *   **Issue:** `dimLineHeightEndY` is calculated as `rectangleY + rectangleHeight + dimLineOffset`. It should be `rectangleY + rectangleHeight + dimLineOffset`.
#     *   **Issue:** The arrows are not drawn at the correct endpoint. The `drawArrow` function's end points are set to the corner of the rectangle. The arrows needs to point to the start and end of the dimension line.
#
# *   **Rule 6 (Labels (Width and Height)):**
#     *   **Issue:** `labelWidthX` is calculated as `(rectangleX + rectangleWidth/2)`. It should be `(dimLineWidthStartX + dimLineWidthEndX) / 2`.
#     *   **Issue:** `labelHeightX` is calculated as `rectangleX - 35`. There is no correlation with `dimLineHeightStartX`.

# %%
issues = response.text

# %%
def remaker_output_prompt(code: str, issues: str) -> str:
    return (
        f"""
        You are a developer specializing in HTML canvas/ JS code and your task is to analyze the given CODE and try 
        to fix these ISSUES and return the new output.

        CODE: {code}
        ISSUES: {issues}
        """
    )

# %%
issues_prompt = remaker_output_prompt(output, issues)
response = model.generate_content(issues_prompt)

# %%
print(response.text)
# Out:
# ```html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Rectangle with Dimensions</title>
# <style>
#   body {
#     font-family: sans-serif;
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     min-height: 100vh;
#     margin: 0;
#     background-color: #f0f0f0;
#   }
#   canvas {
#     border: 1px solid #000;
#     background-color: #fff;
#   }
# </style>
# </head>
# <body>
#
# <canvas id="myCanvas"></canvas>
#
# <script>
# // Helper function to draw an arrow
# function drawArrow(ctx, fromX, fromY, toX, toY, headLength, headAngle) {
#   const angle = Math.atan2(toY - fromY, toX - fromX);
#   ctx.beginPath();
#   ctx.moveTo(fromX, fromY);
#   ctx.lineTo(toX, toY);
#   ctx.stroke();
#
#   ctx.beginPath();
#   ctx.moveTo(toX, toY);
#   ctx.lineTo(toX - headLength * Math.cos(angle - headAngle), toY - headLength * Math.sin(angle - headAngle));
#   ctx.moveTo(toX, toY);
#   ctx.lineTo(toX - headLength * Math.cos(angle + headAngle), toY - headLength * Math.sin(angle + headAngle));
#   ctx.stroke();
# }
#
# // Helper function to draw text
# function drawText(ctx, text, x, y, alignment) {
#   ctx.textAlign = alignment;
#   ctx.fillText(text, x, y);
# }
#
# // Initialize Canvas
# const canvas = document.getElementById("myCanvas");
# const ctx = canvas.getContext("2d");
# canvas.width = 500;
# canvas.height = 300;
#
# // Define Rectangle Properties
# const rectangleWidth = 200;
# const rectangleHeight = 100;
# const rectangleX = (canvas.width / 2) - (rectangleWidth / 2);
# const rectangleY = (canvas.height / 2) - (rectangleHeight / 2);
# const lineColor = 'black';
# const lineWidth = 2;
#
# // Draw Rectangle
# ctx.strokeStyle = lineColor;
# ctx.lineWidth = lineWidth;
# ctx.strokeRect(rectangleX, rectangleY, rectangleWidth, rectangleHeight);
#
# // Draw Dimension Line (Longer Side - Width)
# const dimLineOffset = 20;
# const dimLineWidthStartX = rectangleX - dimLineOffset;
# const dimLineWidthStartY = rectangleY - dimLineOffset;
# const dimLineWidthEndX = rectangleX + rectangleWidth + dimLineOffset;
# const dimLineWidthEndY = rectangleY - dimLineOffset;
# drawArrow(ctx, dimLineWidthStartX, dimLineWidthStartY, rectangleX, rectangleY- dimLineOffset, 10, Math.PI/6);
# drawArrow(ctx, dimLineWidthEndX, dimLineWidthEndY, rectangleX + rectangleWidth, rectangleY- dimLineOffset, 10, Math.PI/6);
#
#
# // Draw Dimension Line (Shorter Side - Height)
# const dimLineHeightStartX = rectangleX - dimLineOffset;
# const dimLineHeightStartY = rectangleY;
# const dimLineHeightEndX = rectangleX - dimLineOffset;
# const dimLineHeightEndY = rectangleY + rectangleHeight + dimLineOffset;
# drawArrow(ctx, dimLineHeightStartX, dimLineHeightStartY, rectangleX - dimLineOffset, rectangleY, 10, Math.PI/6);
# drawArrow(ctx, dimLineHeightEndX, dimLineHeightEndY, rectangleX - dimLineOffset, rectangleY + rectangleHeight, 10, Math.PI/6);
#
# // Draw Labels
# ctx.font = "16px Arial";
# const textColor = 'black';
# ctx.fillStyle = textColor;
#
# // Label for the longer side (width)
# const labelWidthX = (dimLineWidthStartX + dimLineWidthEndX) / 2;
# const labelWidthY = dimLineWidthStartY - 10; // Place above dimension line
# drawText(ctx, "30 cm", labelWidthX, labelWidthY, "center");
#
# // Label for the shorter side (height)
# const labelHeightX = dimLineHeightStartX - 35; // Place to the left of the dimension line
# const labelHeightY = (dimLineHeightStartY + dimLineHeightEndY) / 2;
# drawText(ctx, "15 cm", labelHeightX, labelHeightY, "center");
# </script>
#
# </body>
# </html>
# ```
